# %%
# !wget wget https://www.dropbox.com/s/guaey65lpf49ir5/train.zip?dl=0
# !unzip train.zip?dl=0
# Out:
# --2022-05-01 01:07:47--  http://wget/
# Resolving wget (wget)... failed: No such host is known. .
# wget: unable to resolve host address 'wget'
# --2022-05-01 01:07:53--  https://www.dropbox.com/s/guaey65lpf49ir5/train.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... failed: This is usually a temporary error during hostname resolution and means that the local server did not receive a response from an authoritative server. .
# wget: unable to resolve host address 'www.dropbox.com'
# 'unzip' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from keras.layers import Flatten, Dense
from keras.models import Model
from keras.preprocessing.image import ImageDataGenerator , img_to_array, load_img
from keras.applications.mobilenet import MobileNet, preprocess_input 
from keras.losses import categorical_crossentropy

# %% [markdown]
# #  Building our Model To train the data

# %%
# Working with pre trained model 

base_model = MobileNet( input_shape=(224,224,3), include_top= False )

for layer in base_model.layers:
  layer.trainable = False


x = Flatten()(base_model.output)
x = Dense(units=7 , activation='softmax' )(x)

# creating our model.
model = Model(base_model.input, x)

# %%
model.compile(optimizer='adam', loss= categorical_crossentropy , metrics=['accuracy']  )

# %% [markdown]
# # Preparing our data using data generator

# %%
train_datagen = ImageDataGenerator(
     zoom_range = 0.2, 
     shear_range = 0.2, 
     horizontal_flip=True, 
     rescale = 1./255
)

train_data = train_datagen.flow_from_directory(directory= "/content/train", 
                                               target_size=(224,224), 
                                               batch_size=32,
                                  )


train_data.class_indices
# Out:
# Found 350 images belonging to 7 classes.
# {'Angry': 0,
#  'Disguist': 1,
#  'Fear': 2,
#  'Happy': 3,
#  'Neutral': 4,
#  'Sad': 5,
#  'Surprise': 6}

# %%
val_datagen = ImageDataGenerator(rescale = 1/255 )

val_data = val_datagen.flow_from_directory(directory= "/content/train", 
                                           target_size=(224,224), 
                                           batch_size=32,
                                  )
# Out:
# Found 350 images belonging to 7 classes.

# %% [markdown]
# # visualizaing the data that is fed to train data gen

# %%
# to visualize the images in the traing data denerator 

t_img , label = train_data.next()

#-----------------------------------------------------------------------------
# function when called will prot the images 
def plotImages(img_arr, label):
  """
  input  :- images array 
  output :- plots the images 
  """
  count = 0
  for im, l in zip(img_arr,label) :
    plt.imshow(im)
    plt.title(im.shape)
    plt.axis = False
    plt.show()
    
    count += 1
    if count == 10:
      break

#-----------------------------------------------------------------------------
# function call to plot the images 
plotImages(t_img, label)

# %% [markdown]
# # having early stopping and model check point

# %%
## having early stopping and model check point 

from keras.callbacks import ModelCheckpoint, EarlyStopping

# early stopping
es = EarlyStopping(monitor='val_accuracy', min_delta= 0.01 , patience= 5, verbose= 1, mode='auto')

# model check point
mc = ModelCheckpoint(filepath="best_model.h5", monitor= 'val_accuracy', verbose= 1, save_best_only= True, mode = 'auto')

# puting call back in a list 
call_back = [es, mc]

# %%
hist = model.fit_generator(train_data, 
                           steps_per_epoch= 10, 
                           epochs= 30, 
                           validation_data= val_data, 
                           validation_steps= 8, 
                           callbacks=[es,mc])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
# Epoch 1/30
# 10/10 [==============================] - ETA: 0s - loss: 9.9252 - accuracy: 0.2201
# Epoch 1: val_accuracy improved from -inf to 0.43359, saving model to best_model.h5
# 10/10 [==============================] - 15s 480ms/step - loss: 9.9252 - accuracy: 0.2201 - val_loss: 5.3149 - val_accuracy: 0.4336
# Epoch 2/30
# 10/10 [==============================] - ETA: 0s - loss: 3.4344 - accuracy: 0.5692
# Epoch 2: val_accuracy improved from 0.43359 to 0.75781, saving model to best_model.h5
# 10/10 [==============================] - 5s 463ms/step - loss: 3.4344 - accuracy: 0.5692 - val_loss: 1.5469 - val_accuracy: 0.7578
# Epoch 3/30
# 10/10 [==============================] - ETA: 0s - loss: 1.0301 - accuracy: 0.8113
# Epoch 3: val_accuracy improved from 0.75781 to 0.91406, saving model to best_model.h5
# 10/10 [==============================] - 4s 435ms/step - loss: 1.0301 - accuracy: 0.8113 - val_loss: 0.4244 - val_accuracy: 0.9141
# Epoch 4/30
# 10/10 [==============================] - ETA: 0s - loss: 0.6754 - accuracy: 0.8616
# Epoch 4: val_accuracy improved from 0.91406 to 0.94141, saving model to best_model.h5
# 10/10 [==============================] - 4s 439ms/step - loss: 0.6754 - accuracy: 0.8616 - val_loss: 0.2773 - val_accuracy: 0.9414
# Epoch 5/30
# 10/10 [==============================] - ETA: 0s - loss: 0.5643 - accuracy: 0.8742
# Epoch 5: val_accuracy did not improve from 0.94141
# 10/10 [==============================] - 4s 426ms/step - loss: 0.5643 - accuracy: 0.8742 - val_loss: 0.2396 - val_accuracy: 0.9414
# Epoch 6/30
# 10/10 [==============================] - ETA: 0s - loss: 0.4668 - accuracy: 0.9057
# Epoch 6: val_accuracy did not improve from 0.94141
# 10/10 [==============================] - 4s 419ms/step - loss: 0.4668 - accuracy: 0.9057 - val_loss: 0.1955 - val_accuracy: 0.9414
# Epoch 7/30
# 10/10 [==============================] - ETA: 0s - loss: 0.2080 - accuracy: 0.9371
# Epoch 7: val_accuracy improved from 0.94141 to 0.96875, saving model to best_model.h5
# 10/10 [==============================] - 4s 444ms/step - loss: 0.2080 - accuracy: 0.9371 - val_loss: 0.0789 - val_accuracy: 0.9688
# Epoch 8/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1317 - accuracy: 0.9686
# Epoch 8: val_accuracy improved from 0.96875 to 0.97656, saving model to best_model.h5
# 10/10 [==============================] - 5s 561ms/step - loss: 0.1317 - accuracy: 0.9686 - val_loss: 0.1071 - val_accuracy: 0.9766
# Epoch 9/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0924 - accuracy: 0.9780
# Epoch 9: val_accuracy improved from 0.97656 to 0.98438, saving model to best_model.h5
# 10/10 [==============================] - 8s 784ms/step - loss: 0.0924 - accuracy: 0.9780 - val_loss: 0.0491 - val_accuracy: 0.9844
# Epoch 10/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1877 - accuracy: 0.9656
# Epoch 10: val_accuracy improved from 0.98438 to 0.99219, saving model to best_model.h5
# 10/10 [==============================] - 4s 445ms/step - loss: 0.1877 - accuracy: 0.9656 - val_loss: 0.0228 - val_accuracy: 0.9922
# Epoch 11/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0941 - accuracy: 0.9717
# Epoch 11: val_accuracy improved from 0.99219 to 0.99609, saving model to best_model.h5
# 10/10 [==============================] - 4s 443ms/step - loss: 0.0941 - accuracy: 0.9717 - val_loss: 0.0119 - val_accuracy: 0.9961
# Epoch 12/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1260 - accuracy: 0.9717
# Epoch 12: val_accuracy did not improve from 0.99609
# 10/10 [==============================] - 4s 427ms/step - loss: 0.1260 - accuracy: 0.9717 - val_loss: 0.0126 - val_accuracy: 0.9961
# Epoch 13/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1174 - accuracy: 0.9654
# Epoch 13: val_accuracy did not improve from 0.99609
# 10/10 [==============================] - 4s 419ms/step - loss: 0.1174 - accuracy: 0.9654 - val_loss: 0.0090 - val_accuracy: 0.9961
# Epoch 14/30
# 10/10 [==============================] - ETA: 0s - loss: 0.0620 - accuracy: 0.9811
# Epoch 14: val_accuracy did not improve from 0.99609
# 10/10 [==============================] - 4s 422ms/step - loss: 0.0620 - accuracy: 0.9811 - val_loss: 0.0241 - val_accuracy: 0.9883
# Epoch 15/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1000 - accuracy: 0.9654
# Epoch 15: val_accuracy did not improve from 0.99609
# 10/10 [==============================] - 4s 420ms/step - loss: 0.1000 - accuracy: 0.9654 - val_loss: 0.0662 - val_accuracy: 0.9805
# Epoch 16/30
# 10/10 [==============================] - ETA: 0s - loss: 0.1396 - accuracy: 0.9654
# Epoch 16: val_accuracy did not improve from 0.99609
# 10/10 [==============================] - 4s 426ms/step - loss: 0.1396 - accuracy: 0.9654 - val_loss: 0.0191 - val_accuracy: 0.9922
# Epoch 16: early stopping

# %%
# Loading the best fit model 
from keras.models import load_model
model = load_model("/content/best_model.h5")

# %%
h =  hist.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c = "red")
plt.title("acc vs v-acc")
plt.show()

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c = "red")
plt.title("loss vs v-loss")
plt.show()

# %%
# just to map o/p values 
op = dict(zip( train_data.class_indices.values(), train_data.class_indices.keys()))

# %%
# path for the image to see if it predics correct class

path = "/content/images (2).jpg"
img = load_img(path, target_size=(224,224) )

i = img_to_array(img)/255
input_arr = np.array([i])
input_arr.shape

pred = np.argmax(model.predict(input_arr))

print(f" the image is of {op[pred]}")

# to display the image  
plt.imshow(input_arr[0])
plt.title("input image")
plt.show()
# Out:
#  the image is of Happy
